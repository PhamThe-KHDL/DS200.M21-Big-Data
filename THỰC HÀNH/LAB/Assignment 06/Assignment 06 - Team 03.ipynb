# %% [markdown]
# **Thành Viên: Phạm Đức Thể, Trần Triệu Vũ, Võ Minh Trí**
#
# **MSSV: 19522253, 19522539, 19522396**
#
# **Lớp: DS200.M21**
#
# **Nội Dung: [Bài tập Kaggle 2](https://www.kaggle.com/competitions/kaggle-assignment-2)**
#
# **[Dataset](https://drive.google.com/drive/folders/1_4D3P1j26LUR2DJ5hQQ7P3HID9Sd2Tfu?usp=sharing)**
#
# **Ngày: 26/05/2022**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/18PWt52MH8ilZFBZpmkcWi4__re1zBCge?usp=sharing)

# %% [markdown]
# # **Big Data - UIT DS200 Kaggle Assignment 6**

# %% [markdown]
# ## **Import Library**

# %%
# !pip install pyspark==3.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark==3.0.1
#   Downloading pyspark-3.0.1.tar.gz (204.2 MB)
#      |████████████████████████████████| 204.2 MB 29 kB/s
# Collecting py4j==0.10.9
#   Downloading py4j-0.10.9-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 41.9 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.0.1-py2.py3-none-any.whl size=204612243 sha256=e0a76a2111719042c577e7d71e64ac0b0fc0bb760abdae87f21bb339214f82b8
#   Stored in directory: /root/.cache/pip/wheels/5e/34/fa/b37b5cef503fc5148b478b2495043ba61b079120b7ff379f9b
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9 pyspark-3.0.1

# %%
import numpy as np
import pandas
import time
import seaborn as sns

from IPython.core.display import display
from pyspark.sql import SparkSession
from pyspark.sql.types import FloatType
from pyspark.sql import functions as f
from pyspark.sql import Row
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StopWordsRemover, RegexTokenizer, HashingTF, IDF, Tokenizer, CountVectorizer, Word2Vec
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression, NaiveBayes, MultilayerPerceptronClassifier, GBTClassifier
from pyspark.ml.evaluation import RegressionEvaluator, MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pprint import pprint
from textblob import TextBlob

sns.set()

spark = SparkSession.builder.appName('BigDataAssignment6').config("spark.executor.memory","8g").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://13223c2346cb:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>BigDataAssignment6</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## **Read Data**

# %%
PATH = '/content/drive/MyDrive/TÀI LIỆU HỌC TẬP ĐẠI HỌC 2019-2023/NĂM 3 2021-2022/HỌC KỲ 2 2021 - 2022/DS200.M21 - PHÂN TÍCH DỮ LIỆU LỚN/THỰC HÀNH/LAB/Assignment06 - 25 05 2022/Dataset/'
schemaTrain = 'polarity FLOAT, id LONG, date_time STRING, query STRING, user STRING, text STRING'
schemaTest = "id LONG, date_time STRING, query STRING, user STRING, text STRING"

# %%
# Read train.csv
train_data = spark.read.csv(PATH+'train.csv', header=True, schema=schemaTrain)
train_data.printSchema()
train_data.show(20,False)
train_data.count()
# Out:
# root
#  |-- polarity: float (nullable = true)
#  |-- id: long (nullable = true)
#  |-- date_time: string (nullable = true)
#  |-- query: string (nullable = true)
#  |-- user: string (nullable = true)
#  |-- text: string (nullable = true)
#
# +--------+----------+----------------------------+--------+---------------+---------------------------------------------------------------------------------------------------------------------+
# |polarity|id        |date_time                   |query   |user           |text                                                                                                                 |
# +--------+----------+----------------------------+--------+---------------+---------------------------------------------------------------------------------------------------------------------+
# |0.0     |1467810369|Mon Apr 06 22:19:45 PDT 2009|NO_QUERY|_TheSpecialOne_|@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D  |
# |0.0     |1467810672|Mon Apr 06 22:19:49 PDT 2009|NO_QUERY|scotthamilton  |is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah
------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
# 498

# %%
train = train_data.select('id','text','polarity')
train.printSchema()
train.show(20,False)
train.count()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- polarity: float (nullable = true)
#
# +----------+---------------------------------------------------------------------------------------------------------------------+--------+
# |id        |text                                                                                                                 |polarity|
# +----------+---------------------------------------------------------------------------------------------------------------------+--------+
# |1467810369|@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D  |0.0     |
# |1467810672|is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!      |0.0     |
# |1467810917|@Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds                            |0.0     |
# |1467811184|my whole body feels itchy and like its on fire                                                                       |0.0     |
# |1467811193|@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.       |0.0     |
# |1467811372|@Kwesidei not the whole crew                                                                                         |0.0     |
# |1467811592|Need a hug                                                                                                           |0.0     |
# |1467811594|@LOLTrish hey  long time no see! Yes.. Rains a bit ,only a bit  LOL , I'm fine thanks , how's you ?                  |0.0     |
# |1467811795|@Tatiana_K nope they didn't have it                                                                                  |0.0     |
# |1467812025|@twittera que me muera ?                                                                                             |0.0     |
# |1467812416|spring break in plain city... it's snowing                                                                           |0.0     |
# |1467812579|I just re-pierced my ears                                                                                            |0.0     |
# |1467812723|@caregiving I couldn't bear to watch it.  And I thought the UA loss was embarrassing . . . . .                       |0.0     |
# |1467812771|@octolinz16 It it counts, idk why I did either. you never talk to me anymore                                         |0.0     |
# |1467812784|@smarrison i would've been the first, but i didn't have a gun.    not really though, zac snyder's just a doucheclown.|0.0     |
# |1467812799|@iamjazzyfizzle I wish I got to watch it with you!! I miss you and @iamlilnicki  how was the premiere?!              |0.0     |
# |1467812964|Hollis' death scene will hurt me severely to watch on film  wry is directors cut not out now?                        |0.0     |
# |1467813137|about to file taxes                                                                                                  |0.0     |
# |1467813579|@LettyA ahh ive always wanted to see rent  love the soundtrack!!                                                     |0.0     |
# |1467813782|@FakerPattyPattz Oh dear. Were you drinking out of the forgotten table drinks?                                       |0.0     |
# +----------+---------------------------------------------------------------------------------------------------------------------+--------+
# only showing top 20 rows
# 1600000

# %%
test = test_data.select('id','text')
test.printSchema()
test.show(20,False)
test.count()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- text: string (nullable = true)
#
# +---+--------------------------------------------------------------------------------------------------------------------------------------------+
# |id |text                                                                                                                                        |
# +---+--------------------------------------------------------------------------------------------------------------------------------------------+
# |3  |@stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.                             |
# |4  |Reading my kindle2...  Love it... Lee childs is good read.                                                                                  |
# |5  |Ok, first assesment of the #kindle2 ...it fucking rocks!!!                                                                                  |
# |6  |@kenburbary You'll love your Kindle2. I've had mine for a few months and never looked back. The new big one is huge! No need for remorse! :)|
# |7  |@mikefish  Fair enough. But i have the Kindle2 and I think it's perfect  :)                                                                 |
# |8  |@richardebaker no. it is too big. I'm quite happy with the Kindle2.                                                                         |
# |9  |Fuck this economy. I hate aig and their non loan given asses.                                                                               |
# |10 |Jquery is my new best friend.                                                                                                               |
# |11 |Loves twitter                                                                                                                               |
# |12 |how can you not love Obama? he makes jokes about himself.                                                                                   |
# |13 |Check this video out -- President Obama at the White House Correspondents' Dinner http://bit.ly/IMXUM                                       |
# |14 |@Karoli I firmly believe that Obama/Pelosi have ZERO desire to be civil.  It's a charade and a slogan, but they want to destroy conservatism|
# |15 |House Correspondents dinner was last night whoopi, barbara &amp; sherri went, Obama got a standing ovation                                  |
# |16 |Watchin Espn..Jus seen this new Nike Commerical with a Puppet Lebron..sh*t was hilarious...LMAO!!!                                          |
# |17 |dear nike, stop with the flywire. that shit is a waste of science. and ugly. love, @vincentx24x                                             |
# |18 |#lebron best athlete of our generation, if not all time (basketball related) I don't want to get into inter-sport debates about   __1/2     |
# |19 |I was talking to this guy last night and he was telling me that he is a die hard Spurs fan.  He also told me that he hates LeBron James.    |
# |20 |i love lebron. http://bit.ly/PdHur                                                                                                          |
# |21 |@ludajuice Lebron is a Beast, but I'm still cheering 4 the A..til the end.                                                                  |
# |22 |@Pmillzz lebron IS THE BOSS                                                                                                                 |
# +---+--------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
# 498

# %% [markdown]
# ### distribution of polarity train

# %%
df = train.select('polarity').na.drop()
print(f'No of rows with Polarity: {df.count()}/{train.count()}')

sns.distplot(df.toPandas())
# Out:
# No of rows with Polarity: 1600000/1600000
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
polarity_df = train.select('polarity').cache()

polarity_df.groupBy('polarity').count().toPandas()
# Out:
#    polarity   count
# 0       4.0  800000
# 1       0.0  800000

# %% [markdown]
# ### Encode train polarity

# %%
# train = train.withColumn('polarity',f.when(f.col('polarity')==4, 2).otherwise(0))

# %%
# df = train.select('polarity').na.drop()
# print(f'No of rows with Polarity: {df.count()}/{train.count()}')

# sns.distplot(df.toPandas())

# %%
# polarity_df = train.select('polarity').cache()

# polarity_df.groupBy('polarity').count().toPandas()

# %% [markdown]
# ## **Text Pre-processing**

# %%
def cleaning_process(data):
  user_regex = r'(@\w{1,15})'
  hashtag_replace_regex = '(#\w{1,})'
  data_new = data.withColumn('users_mentioned', (f.array_remove(f.array(f.regexp_extract(f.col('text'), user_regex, 1),
                                                                        f.regexp_extract(f.col('text'), ''.join([f'{user_regex}.*?' for i in range(0,2)]), 2),
                                                                        f.regexp_extract(f.col('text'), ''.join([f'{user_regex}.*?' for i in range(0,3)]), 3),
                                                                        f.regexp_extract(f.col('text'), ''.join([f'{user_regex}.*?' for i in range(0,4)]), 4),
                                                                        f.regexp_extract(f.col('text'), ''.join([f'{user_regex}.*?' for i in range(0,5)]), 5),
                                                                        f.regexp_extract(f.col('text'), ''.join([f'{user_regex}.*?' for i in range(0,6)]), 6),),'',))) \
                  .withColumn('hashtags', f.array_remove(f.array(f.regexp_extract(f.col('text'), hashtag_replace_regex, 1),
                                                                 f.regexp_extract(f.col('text'), ''.join([f'{hashtag_replace_regex}.*?' for i in range(0,2)]), 2),
                                                                 f.regexp_extract(f.col('text'), ''.join([f'{hashtag_replace_regex}.*?' for i in range(0,3)]), 3),
                                                                 f.regexp_extract(f.col('text'), ''.join([f'{hashtag_replace_regex}.*?' for i in range(0,4)]), 4),
                                                                 f.regexp_extract(f.col('text'), ''.join([f'{hashtag_replace_regex}.*?' for i in range(0,5)]), 5),
                                                                 f.regexp_extract(f.col('text'), ''.join([f'{hashtag_replace_regex}.*?' for i in range(0,6)]), 6),),'',))
                    
  return data_new

# %%
train_cleaning = cleaning_process(train)
test_cleaning = cleaning_process(test)

# %%
train_cleaning.printSchema()
train_cleaning.show(20,False)
train_cleaning.count()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- polarity: float (nullable = true)
#  |-- users_mentioned: array (nullable = false)
#  |    |-- element: string (containsNull = true)
#  |-- hashtags: array (nullable = false)
#  |    |-- element: string (containsNull = true)
#
# +----------+---------------------------------------------------------------------------------------------------------------------+--------+-------------------------------+--------+
# |id        |text                                                                                                                 |polarity|users_mentioned                |hashtags|
# +----------+---------------------------------------------------------------------------------------------------------------------+--------+-------------------------------+--------+
# |1467810369|@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D  |0.0     |[@switchfoot]                  |[]      |
# |1467810672|is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!      |0.0     |[]                             |[]      |
# |1467810917|@Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds                            |0.0     |[@Kenichan]                    |[]      |
# |1467811184|my whole body feels itchy and like its on fire                                                                       |0.0     |[]                             |[]      |
# |1467811193|@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there.       |0.0     |[@nationwideclass]             |[]      |
# |1467811372|@Kwesidei not the whole crew                                                                                         |0.0     |[@Kwesidei]                    |[]      |
# |1467811592|Need a hug                                                                                                           |0.0     |[]                             |[]      |
# |1467811594|@LOLTrish hey  long time no see! Yes.. Rains a bit ,only a bit  LOL , I'm fine thanks , how's you ?                  |0.0     |[@LOLTrish]                    |[]      |
# |1467811795|@Tatiana_K nope they didn't have it                                                                                  |0.0     |[@Tatiana_K]                   |[]      |
# |1467812025|@twittera que me muera ?                                                                                             |0.0     |[@twittera]                    |[]      |
# |1467812416|spring break in plain city... it's snowing                                                                           |0.0     |[]                             |[]      |
# |1467812579|I just re-pierced my ears                                                                                            |0.0     |[]                             |[]      |
# |1467812723|@caregiving I couldn't bear to watch it.  And I thought the UA loss was embarrassing . . . . .                       |0.0     |[@caregiving]                  |[]      |
# |1467812771|@octolinz16 It it counts, idk why I did either. you never talk to me anymore                                         |0.0     |[@octolinz16]                  |[]      |
# |1467812784|@smarrison i would've been the first, but i didn't have a gun.    not really though, zac snyder's just a doucheclown.|0.0     |[@smarrison]                   |[]      |
# |1467812799|@iamjazzyfizzle I wish I got to watch it with you!! I miss you and @iamlilnicki  how was the premiere?!              |0.0     |[@iamjazzyfizzle, @iamlilnicki]|[]      |
# |1467812964|Hollis' death scene will hurt me severely to watch on film  wry is directors cut not out now?                        |0.0     |[]                             |[]      |
# |1467813137|about to file taxes                                                                                                  |0.0     |[]                             |[]      |
# |1467813579|@LettyA ahh ive always wanted to see rent  love the soundtrack!!                                                     |0.0     |[@LettyA]                      |[]      |
# |1467813782|@FakerPattyPattz Oh dear. Were you drinking out of the forgotten table drinks?                                       |0.0     |[@FakerPattyPattz]             |[]      |
# +----------+---------------------------------------------------------------------------------------------------------------------+--------+-------------------------------+--------+
# only showing top 20 rows
# 1600000

# %%
test_cleaning.printSchema()
test_cleaning.show(20,False)
test_cleaning.count()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- users_mentioned: array (nullable = false)
#  |    |-- element: string (containsNull = true)
#  |-- hashtags: array (nullable = false)
#  |    |-- element: string (containsNull = true)
#
# +---+--------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------+
# |id |text                                                                                                                                        |users_mentioned |hashtags  |
# +---+--------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------+
# |3  |@stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.                             |[@stellargirl]  |[]        |
# |4  |Reading my kindle2...  Love it... Lee childs is good read.                                                                                  |[]              |[]        |
# |5  |Ok, first assesment of the #kindle2 ...it fucking rocks!!!                                                                                  |[]              |[#kindle2]|
# |6  |@kenburbary You'll love your Kindle2. I've had mine for a few months and never looked back. The new big one is huge! No need for remorse! :)|[@kenburbary]   |[]        |
# |7  |@mikefish  Fair enough. But i have the Kindle2 and I think it's perfect  :)                                                                 |[@mikefish]     |[]        |
# |8  |@richardebaker no. it is too big. I'm quite happy with the Kindle2.                                                                         |[@richardebaker]|[]        |
# |9  |Fuck this economy. I hate aig and their non loan given asses.                                                                               |[]              |[]        |
# |10 |Jquery is my new best friend.                                                                                                               |[]              |[]        |
# |11 |Loves twitter                                                                                                                               |[]              |[]        |
# |12 |how can you not love Obama? he makes jokes about himself.                                                                                   |[]              |[]        |
# |13 |Check this video out -- President Obama at the White House Correspondents' Dinner http://bit.ly/IMXUM                                       |[]              |[]        |
# |14 |@Karoli I firmly believe that Obama/Pelosi have ZERO desire to be civil.  It's a charade and a slogan, but they want to destroy conservatism|[@Karoli]       |[]        |
# |15 |House Correspondents dinner was last night whoopi, barbara &amp; sherri went, Obama got a standing ovation                                  |[]              |[]        |
# |16 |Watchin Espn..Jus seen this new Nike Commerical with a Puppet Lebron..sh*t was hilarious...LMAO!!!                                          |[]              |[]        |
# |17 |dear nike, stop with the flywire. that shit is a waste of science. and ugly. love, @vincentx24x                                             |[@vincentx24x]  |[]        |
# |18 |#lebron best athlete of our generation, if not all time (basketball related) I don't want to get into inter-sport debates about   __1/2     |[]              |[#lebron] |
# |19 |I was talking to this guy last night and he was telling me that he is a die hard Spurs fan.  He also told me that he hates LeBron James.    |[]              |[]        |
# |20 |i love lebron. http://bit.ly/PdHur                                                                                                          |[]              |[]        |
# |21 |@ludajuice Lebron is a Beast, but I'm still cheering 4 the A..til the end.                                                                  |[@ludajuice]    |[]        |
# |22 |@Pmillzz lebron IS THE BOSS                                                                                                                 |[@Pmillzz]      |[]        |
# +---+--------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------+
# only showing top 20 rows
# 498

# %%
df_training = (
    train_cleaning
    # Remove all numbers
    .withColumn("text", f.regexp_replace(f.col("text"), "[^a-zA-Z]", " "))
    # Remove all double/multiple spaces
    .withColumn("text", f.regexp_replace(f.col("text"), " +", " "))
    # Remove leading and training whitespaces
    .withColumn("text", f.trim(f.col("text")))
    # Ensure we don't end up with empty rows
    .filter("text != ' '"))
Train = df_training.select("text", "polarity").coalesce(3).cache()
Train.printSchema()
Train.show(20,False)
Train.count()
# Out:
# root
#  |-- text: string (nullable = true)
#  |-- polarity: float (nullable = true)
#
# +-------------------------------------------------------------------------------------------------------------+--------+
# |text                                                                                                         |polarity|
# +-------------------------------------------------------------------------------------------------------------+--------+
# |switchfoot http twitpic com y zl Awww that s a bummer You shoulda got David Carr of Third Day to do it D     |0.0     |
# |is upset that he can t update his Facebook by texting it and might cry as a result School today also Blah    |0.0     |
# |Kenichan I dived many times for the ball Managed to save The rest go out of bounds                           |0.0     |
# |my whole body feels itchy and like its on fire                                                               |0.0     |
# |nationwideclass no it s not behaving at all i m mad why am i here because I can t see you all over there     |0.0     |
# |Kwesidei not the whole crew                                                                                  |0.0     |
# |Need a hug                                                                                                   |0.0     |
# |LOLTrish hey long time no see Yes Rains a bit only a bit LOL I m fine thanks how s you                       |0.0     |
# |Tatiana K nope they didn t have it                                                                           |0.0     |
# |twittera que me muera                                                                                        |0.0     |
# |spring break in plain city it s snowing                                                                      |0.0     |
# |I just re pierced my ears                                                                                    |0.0     |
# |caregiving I couldn t bear to watch it And I thought the UA loss was embarrassing                            |0.0     |
# |octolinz It it counts idk why I did either you never talk to me anymore                                      |0.0     |
# |smarrison i would ve been the first but i didn t have a gun not really though zac snyder s just a doucheclown|0.0     |
# |iamjazzyfizzle I wish I got to watch it with you I miss you and iamlilnicki how was the premiere             |0.0     |
# |Hollis death scene will hurt me severely to watch on film wry is directors cut not out now                   |0.0     |
# |about to file taxes                                                                                          |0.0     |
# |LettyA ahh ive always wanted to see rent love the soundtrack                                                 |0.0     |
# |FakerPattyPattz Oh dear Were you drinking out of the forgotten table drinks                                  |0.0     |
# +-------------------------------------------------------------------------------------------------------------+--------+
# only showing top 20 rows
# 1600000

# %%
df_test = (
    test_cleaning
    # Remove all numbers
    .withColumn("text", f.regexp_replace(f.col("text"), "[^a-zA-Z]", " "))
    # Remove all double/multiple spaces
    .withColumn("text", f.regexp_replace(f.col("text"), " +", " "))
    # Remove leading and training whitespaces
    .withColumn("text", f.trim(f.col("text")))
    # Ensure we don't end up with empty rows
    .filter("text != ' '"))
Test = df_test.select('id', "text").coalesce(3).cache()
Test.printSchema()
Test.show(20,False)
Test.count()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- text: string (nullable = true)
#
# +---+----------------------------------------------------------------------------------------------------------------------------------------+
# |id |text                                                                                                                                    |
# +---+----------------------------------------------------------------------------------------------------------------------------------------+
# |3  |stellargirl I loooooooovvvvvveee my Kindle Not that the DX is cool but the is fantastic in its own right                                |
# |4  |Reading my kindle Love it Lee childs is good read                                                                                       |
# |5  |Ok first assesment of the kindle it fucking rocks                                                                                       |
# |6  |kenburbary You ll love your Kindle I ve had mine for a few months and never looked back The new big one is huge No need for remorse     |
# |7  |mikefish Fair enough But i have the Kindle and I think it s perfect                                                                     |
# |8  |richardebaker no it is too big I m quite happy with the Kindle                                                                          |
# |9  |Fuck this economy I hate aig and their non loan given asses                                                                             |
# |10 |Jquery is my new best friend                                                                                                            |
# |11 |Loves twitter                                                                                                                           |
# |12 |how can you not love Obama he makes jokes about himself                                                                                 |
# |13 |Check this video out President Obama at the White House Correspondents Dinner http bit ly IMXUM                                         |
# |14 |Karoli I firmly believe that Obama Pelosi have ZERO desire to be civil It s a charade and a slogan but they want to destroy conservatism|
# |15 |House Correspondents dinner was last night whoopi barbara amp sherri went Obama got a standing ovation                                  |
# |16 |Watchin Espn Jus seen this new Nike Commerical with a Puppet Lebron sh t was hilarious LMAO                                             |
# |17 |dear nike stop with the flywire that shit is a waste of science and ugly love vincentx x                                                |
# |18 |lebron best athlete of our generation if not all time basketball related I don t want to get into inter sport debates about             |
# |19 |I was talking to this guy last night and he was telling me that he is a die hard Spurs fan He also told me that he hates LeBron James   |
# |20 |i love lebron http bit ly PdHur                                                                                                         |
# |21 |ludajuice Lebron is a Beast but I m still cheering the A til the end                                                                    |
# |22 |Pmillzz lebron IS THE BOSS                                                                                                              |
# +---+----------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
# 498

# %% [markdown]
# ## **Build Model**

# %% [markdown]
# ### Build Pipeline

# %%
# Create pipeline processing data and model
regexTokenizer = RegexTokenizer(inputCol="text", outputCol="words", pattern="\\W")
stopwords_remover = StopWordsRemover(inputCol="words", outputCol="words1", 
                                     stopWords=StopWordsRemover.loadDefaultStopWords("english"))
hashing_tf = HashingTF(numFeatures=2**17, inputCol="words1", outputCol='term_frequency')
idf = IDF(inputCol='term_frequency', outputCol="features", minDocFreq=25) #minDocFreq: remove sparse terms
label_stringIdx = StringIndexer(inputCol = "polarity", outputCol = "label")
lr = LogisticRegression(maxIter=5000, regParam = 0.001, featuresCol="features", labelCol="polarity")

pipeline = Pipeline(stages=[regexTokenizer, stopwords_remover, hashing_tf, idf, label_stringIdx, lr])

# %% [markdown]
# **Model:**
#
# ```python
# # Create pipeline processing data and model
# regexTokenizer = RegexTokenizer(inputCol="text", outputCol="words", pattern="\\W")
# stopwords_remover = StopWordsRemover(inputCol="words", outputCol="words1",
#                                      stopWords=StopWordsRemover.loadDefaultStopWords("english"))
# hashing_tf = HashingTF(numFeatures=2**17, inputCol="words1", outputCol='term_frequency')
# idf = IDF(inputCol='term_frequency', outputCol="features", minDocFreq=25) #minDocFreq: remove sparse terms
# # label_stringIdx = StringIndexer(inputCol = "polarity", outputCol = "label")
# lr = LogisticRegression(maxIter=300, regParam = 0.005, featuresCol="features", labelCol="polarity")
#
# pipeline = Pipeline(stages=[regexTokenizer, stopwords_remover, hashing_tf, idf, lr])
# ```

# %%
# %%time
model = pipeline.fit(Train)
# Out:
# CPU times: user 1.32 s, sys: 167 ms, total: 1.49 s
# Wall time: 3min 16s

# %%
Trained = model.transform(Train)
Trained.show()
# Out:
# +--------------------+--------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+----------+
# |                text|polarity|               words|              words1|      term_frequency|            features|label|       rawPrediction|         probability|prediction|
# +--------------------+--------+--------------------+--------------------+--------------------+--------------------+-----+--------------------+--------------------+----------+
# |switchfoot http t...|     0.0|[switchfoot, http...|[switchfoot, http...|(131072,[17699,21...|(131072,[17699,21...|  0.0|[9.78718038301342...|[0.96290142476768...|       0.0|
# |is upset that he ...|     0.0|[is, upset, that,...|[upset, update, f...|(131072,[16064,19...|(131072,[16064,19...|  0.0|[10.1131330191109...|[0.98035980274585...|       0.0|
# | 20|i love lebron htt...|[i, love, lebron,...|[love, lebron, ht...|(131072,[6693,554...|(131072,[6693,554...|[7.43547249685910...|[0.19114350738929...|       4.0|
# | 21|ludajuice Lebron ...|[ludajuice, lebro...|[ludajuice, lebro...|(131072,[25845,31...|(131072,[25845,31...|[8.59191714900592...|[0.70450896989767...|       0.0|
# | 22|Pmillzz lebron IS...|[pmillzz, lebron,...|[pmillzz, lebron,...|(131072,[33540,48...|(131072,[33540,48...|[8.09116695184657...|[0.46756150857032...|       4.0|
# +---+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
# %%time

evaluator = MulticlassClassificationEvaluator(labelCol='polarity', metricName='accuracy')
accuracy_train = evaluator.evaluate(Trained)

print('='*15+'Training Data'+'='*15)
print(f'Accuracy: {accuracy_train*100:.5f}%')
# Out:
# ===============Training Data===============
# Accuracy: 78.82488%
# CPU times: user 1.79 s, sys: 254 ms, total: 2.04 s
# Wall time: 4min 55s

# %% [markdown]
# **Output:**
#
# ```python
# ===============Training Data===============
# Accuracy: 78.81681%
# CPU times: user 1.64 s, sys: 203 ms, total: 1.84 s
# Wall time: 4min 53s
# ```

# %% [markdown]
# ## **Prediction**

# %% [markdown]
# ### Predict on Test

# %%
predictions = model.transform(Test)
predictions.show()
predictions.count()
# Out:
# +---+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# | id|                text|               words|              words1|      term_frequency|            features|       rawPrediction|         probability|prediction|
# +---+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |  3|stellargirl I loo...|[stellargirl, i, ...|[stellargirl, loo...|(131072,[21494,61...|(131072,[21494,61...|[7.10208811781137...|[0.10819043057537...|       4.0|
# |  4|Reading my kindle...|[reading, my, kin...|[reading, kindle,...|(131072,[53570,55...|(131072,[53570,55...|[7.02292955665899...|[0.09379932444915...|       4.0|
# |  5|Ok first assesmen...|[ok, first, asses...|[ok, first, asses...|(131072,[1527,417...|(131072,[1527,417...|[7.54926433817486...|[0.22873528051659...|       4.0|
# |  6|kenburbary You ll...|[kenburbary, you,...|[kenburbary, ll, ...|(131072,[1198,154...|(131072,[1198,154...|[8.72227055294863...|[0.75510844427348...|       0.0|
# |  7|mikefish Fair eno...|[mikefish, fair, ...|[mikefish, fair, ...|(131072,[5802,223...|(131072,[5802,223...|[8.20163392584665...|[0.52239693449853...|       0.0|
# |  8|richardebaker no ...|[richardebaker, n...|[richardebaker, b...|(131072,[41816,50...|(131072,[41816,50...|[7.30756523094002...|[0.15467900663555...|       4.0|
# |  9|Fuck this economy...|[fuck, this, econ...|[fuck, economy, h...|(131072,[16474,69...|(131072,[16474,69...|[9.85015846894439...|[0.96726457926239...|       0.0|
# | 10|Jquery is my new ...|[jquery, is, my, ...|[jquery, new, bes...|(131072,[34824,34...|(131072,[34824,34...|[7.32466477398116...|[0.15925577602173...|       4.0|
# | 11|       Loves twitter|    [loves, twitter]|    [loves, twitter]|(131072,[1512,115...|(131072,[1512,115...|[7.40003419837611...|[0.18061380200348...|       4.0|
# | 12|how can you not l...|[how, can, you, n...|[love, obama, mak...|(131072,[27773,55...|(131072,[27773,55...|[7.33747277489098...|[0.16271661341045...|       4.0|
# | 22|Pmillzz lebron IS...|[0.46756150857032...|       4.0|
# +---+--------------------+--------------------+----------+
# only showing top 20 rows
# 498

# %%
def get_polarity(s):
    return TextBlob(s).sentiment.polarity

# %%
udf1 = f.udf(get_polarity, FloatType())
pred = pred.withColumn('sentiment', udf1(f.col('text')))
pred.show()
pred.count()
# Out:
# +---+--------------------+--------------------+----------+-----------+
# | id|                text|         probability|prediction|  sentiment|
# +---+--------------------+--------------------+----------+-----------+
# |  3|stellargirl I loo...|[0.10819043057537...|       4.0| 0.40892857|
# |  4|Reading my kindle...|[0.09379932444915...|       4.0|        0.6|
# |  5|Ok first assesmen...|[0.22873528051659...|       4.0|       0.05|
# |  6|kenburbary You ll...|[0.75510844427348...|       0.0| 0.13939394|
# |  7|mikefish Fair eno...|[0.52239693449853...|       0.0| 0.56666666|
# |  8|richardebaker no ...|[0.15467900663555...|       4.0|        0.4|
# |  9|Fuck this economy...|[0.96726457926239...|       0.0|       -0.6|
# | 10|Jquery is my new ...|[0.15925577602173...|       4.0|  0.5681818|
# | 11|       Loves twitter|[0.18061380200348...|       4.0|        0.0|
# | 12|how can you not l...|[0.16271661341045...|       4.0|      -0.25|
# | 13|Check this video ...|[0.10648947649677...|       4.0|        0.0|
# | 14|Karoli I firmly b...|[0.77286910297385...|       0.0|       -0.2|
# | 15|House Corresponde...|[0.28247008059715...|       4.0|        0.0|
# | 16|Watchin Espn Jus ...|[0.10770404199482...|       4.0|  0.4121212|
# | 17|dear nike stop wi...|[0.76093995735099...|       0.0|      -0.15|
# | 18|lebron best athle...|[0.71061657524261...|       0.0|        0.5|
# | 19|I was talking to ...|[0.93750559309597...|       0.0|-0.14583333|
# | 20|i love lebron htt...|[0.19114350738929...|       4.0|        0.5|
# | 21|ludajuice Lebron ...|[0.70450896989767...|       0.0|        0.0|
# | 22|Pmillzz lebron IS...|[0.46756150857032...|       4.0|        0.0|
# +---+--------------------+--------------------+----------+-----------+
# only showing top 20 rows
# 498

# %%
pred = pred.withColumn('polarity',f.when(f.col('sentiment')<0, 0).when(f.col('sentiment')==0, 2).otherwise(4))
pred.show()
pred.count()
# Out:
# +---+--------------------+--------------------+----------+-----------+--------+
# | id|                text|         probability|prediction|  sentiment|polarity|
# +---+--------------------+--------------------+----------+-----------+--------+
# |  3|stellargirl I loo...|[0.10819043057537...|       4.0| 0.40892857|       4|
# |  4|Reading my kindle...|[0.09379932444915...|       4.0|        0.6|       4|
# |  5|Ok first assesmen...|[0.22873528051659...|       4.0|       0.05|       4|
# |  6|kenburbary You ll...|[0.75510844427348...|       0.0| 0.13939394|       4|
# |  7|mikefish Fair eno...|[0.52239693449853...|       0.0| 0.56666666|       4|
# |  8|richardebaker no ...|[0.15467900663555...|       4.0|        0.4|       4|
# |  9|Fuck this economy...|[0.96726457926239...|       0.0|       -0.6|       0|
# | 10|Jquery is my new ...|[0.15925577602173...|       4.0|  0.5681818|       4|
# | 11|       Loves twitter|[0.18061380200348...|       4.0|        0.0|       2|
# | 12|how can you not l...|[0.16271661341045...|       4.0|      -0.25|       0|
# | 13|Check this video ...|[0.10648947649677...|       4.0|        0.0|       2|
# | 14|Karoli I firmly b...|[0.77286910297385...|       0.0|       -0.2|       0|
# | 15|House Corresponde...|[0.28247008059715...|       4.0|        0.0|       2|
# | 16|Watchin Espn Jus ...|[0.10770404199482...|       4.0|  0.4121212|       4|
# | 17|dear nike stop wi...|[0.76093995735099...|       0.0|      -0.15|       0|
# | 18|lebron best athle...|[0.71061657524261...|       0.0|        0.5|       4|
# | 19|I was talking to ...|[0.93750559309597...|       0.0|-0.14583333|       0|
# | 20|i love lebron htt...|[0.19114350738929...|       4.0|        0.5|       4|
# | 21|ludajuice Lebron ...|[0.70450896989767...|       0.0|        0.0|       2|
# | 22|Pmillzz lebron IS...|[0.46756150857032...|       4.0|        0.0|       2|
# +---+--------------------+--------------------+----------+-----------+--------+
# only showing top 20 rows
# 498

# %%
pred = pred.withColumn('prob', f.col('probability').cast("string").substr(2,4).cast("float"))
pred.show()
pred.count()
# Out:
# +---+--------------------+--------------------+----------+-----------+--------+----+
# | id|                text|         probability|prediction|  sentiment|polarity|prob|
# +---+--------------------+--------------------+----------+-----------+--------+----+
# |  3|stellargirl I loo...|[0.10819043057537...|       4.0| 0.40892857|       4| 0.1|
# |  4|Reading my kindle...|[0.09379932444915...|       4.0|        0.6|       4|0.09|
# |  5|Ok first assesmen...|[0.22873528051659...|       4.0|       0.05|       4|0.22|
# |  6|kenburbary You ll...|[0.75510844427348...|       0.0| 0.13939394|       4|0.75|
# |  7|mikefish Fair eno...|[0.52239693449853...|       0.0| 0.56666666|       4|0.52|
# |  8|richardebaker no ...|[0.15467900663555...|       4.0|        0.4|       4|0.15|
# |  9|Fuck this economy...|[0.96726457926239...|       0.0|       -0.6|       0|0.96|
# | 10|Jquery is my new ...|[0.15925577602173...|       4.0|  0.5681818|       4|0.15|
# | 11|       Loves twitter|[0.18061380200348...|       4.0|        0.0|       2|0.18|
# | 12|how can you not l...|[0.16271661341045...|       4.0|      -0.25|       0|0.16|
# | 13|Check this video ...|[0.10648947649677...|       4.0|        0.0|       2| 0.1|
# | 14|Karoli I firmly b...|[0.77286910297385...|       0.0|       -0.2|       0|0.77|
# | 15|House Corresponde...|[0.28247008059715...|       4.0|        0.0|       2|0.28|
# | 16|Watchin Espn Jus ...|[0.10770404199482...|       4.0|  0.4121212|       4| 0.1|
# | 17|dear nike stop wi...|[0.76093995735099...|       0.0|      -0.15|       0|0.76|
# | 18|lebron best athle...|[0.71061657524261...|       0.0|        0.5|       4|0.71|
# | 19|I was talking to ...|[0.93750559309597...|       0.0|-0.14583333|       0|0.93|
# | 20|i love lebron htt...|[0.19114350738929...|       4.0|        0.5|       4|0.19|
# | 21|ludajuice Lebron ...|[0.70450896989767...|       0.0|        0.0|       2| 0.7|
# | 22|Pmillzz lebron IS...|[0.46756150857032...|       4.0|        0.0|       2|0.46|
# +---+--------------------+--------------------+----------+-----------+--------+----+
# only showing top 20 rows
# 498

# %% [markdown]
# ### Final Result

# %%
final = pred.withColumn('polarity', f.when((f.col('polarity')==4) & (f.col('prob')>0.53),2).otherwise(f.col('polarity')))
final.show()
final.count()
# Out:
# +---+--------------------+--------------------+----------+-----------+--------+----+
# | id|                text|         probability|prediction|  sentiment|polarity|prob|
# +---+--------------------+--------------------+----------+-----------+--------+----+
# |  3|stellargirl I loo...|[0.10819043057537...|       4.0| 0.40892857|       4| 0.1|
# |  4|Reading my kindle...|[0.09379932444915...|       4.0|        0.6|       4|0.09|
# |  5|Ok first assesmen...|[0.22873528051659...|       4.0|       0.05|       4|0.22|
# |  6|kenburbary You ll...|[0.75510844427348...|       0.0| 0.13939394|       2|0.75|
# |  7|mikefish Fair eno...|[0.52239693449853...|       0.0| 0.56666666|       4|0.52|
# |  8|richardebaker no ...|[0.15467900663555...|       4.0|        0.4|       4|0.15|
# |  9|Fuck this economy...|[0.96726457926239...|       0.0|       -0.6|       0|0.96|
# | 10|Jquery is my new ...|[0.15925577602173...|       4.0|  0.5681818|       4|0.15|
# | 11|       Loves twitter|[0.18061380200348...|       4.0|        0.0|       2|0.18|
# | 12|how can you not l...|[0.16271661341045...|       4.0|      -0.25|       0|0.16|
# | 13|Check this video ...|[0.10648947649677...|       4.0|        0.0|       2| 0.1|
# | 14|Karoli I firmly b...|[0.77286910297385...|       0.0|       -0.2|       0|0.77|
# | 15|House Corresponde...|[0.28247008059715...|       4.0|        0.0|       2|0.28|
# | 16|Watchin Espn Jus ...|[0.10770404199482...|       4.0|  0.4121212|       4| 0.1|
# | 17|dear nike stop wi...|[0.76093995735099...|       0.0|      -0.15|       0|0.76|
# | 18|lebron best athle...|[0.71061657524261...|       0.0|        0.5|       2|0.71|
# | 19|I was talking to ...|[0.93750559309597...|       0.0|-0.14583333|       0|0.93|
# | 20|i love lebron htt...|[0.19114350738929...|       4.0|        0.5|       4|0.19|
# | 21|ludajuice Lebron ...|[0.70450896989767...|       0.0|        0.0|       2| 0.7|
# | 22|Pmillzz lebron IS...|[0.46756150857032...|       4.0|        0.0|       2|0.46|
# +---+--------------------+--------------------+----------+-----------+--------+----+
# only showing top 20 rows
# 498

# %%
final = final.withColumn('polarity', f.when((f.col('polarity')==2) & (f.col('prob')>0.55),0).otherwise(f.col('polarity')))
final.show()
final.count()
# Out:
# +---+--------------------+--------------------+----------+-----------+--------+----+
# | id|                text|         probability|prediction|  sentiment|polarity|prob|
# +---+--------------------+--------------------+----------+-----------+--------+----+
# |  3|stellargirl I loo...|[0.10819043057537...|       4.0| 0.40892857|       4| 0.1|
# |  4|Reading my kindle...|[0.09379932444915...|       4.0|        0.6|       4|0.09|
# |  5|Ok first assesmen...|[0.22873528051659...|       4.0|       0.05|       4|0.22|
# |  6|kenburbary You ll...|[0.75510844427348...|       0.0| 0.13939394|       0|0.75|
# |  7|mikefish Fair eno...|[0.52239693449853...|       0.0| 0.56666666|       4|0.52|
# |  8|richardebaker no ...|[0.15467900663555...|       4.0|        0.4|       4|0.15|
# |  9|Fuck this economy...|[0.96726457926239...|       0.0|       -0.6|       0|0.96|
# | 10|Jquery is my new ...|[0.15925577602173...|       4.0|  0.5681818|       4|0.15|
# | 11|       Loves twitter|[0.18061380200348...|       4.0|        0.0|       2|0.18|
# | 12|how can you not l...|[0.16271661341045...|       4.0|      -0.25|       0|0.16|
# | 13|Check this video ...|[0.10648947649677...|       4.0|        0.0|       2| 0.1|
# | 14|Karoli I firmly b...|[0.77286910297385...|       0.0|       -0.2|       0|0.77|
# | 15|House Corresponde...|[0.28247008059715...|       4.0|        0.0|       2|0.28|
# | 16|Watchin Espn Jus ...|[0.10770404199482...|       4.0|  0.4121212|       4| 0.1|
# | 17|dear nike stop wi...|[0.76093995735099...|       0.0|      -0.15|       0|0.76|
# | 18|lebron best athle...|[0.71061657524261...|       0.0|        0.5|       0|0.71|
# | 19|I was talking to ...|[0.93750559309597...|       0.0|-0.14583333|       0|0.93|
# | 20|i love lebron htt...|[0.19114350738929...|       4.0|        0.5|       4|0.19|
# | 21|ludajuice Lebron ...|[0.70450896989767...|       0.0|        0.0|       0| 0.7|
# | 22|Pmillzz lebron IS...|[0.46756150857032...|       4.0|        0.0|       2|0.46|
# +---+--------------------+--------------------+----------+-----------+--------+----+
# only showing top 20 rows
# 498

# %%
final.groupBy('polarity').agg(f.count(f.col('polarity'))).show()
# Out:
# +--------+---------------+
# |polarity|count(polarity)|
# +--------+---------------+
# |       4|            178|
# |       2|            122|
# |       0|            198|
# +--------+---------------+

# %% [markdown]
# **Test**
# ```python
# +--------+---------------+
# |polarity|count(polarity)|
# +--------+---------------+
# |     4.0|            182|
# |     2.0|            139|
# |     0.0|            177|
# +--------+---------------+
# ```
# **Output:**
#
# ```python
# +--------+---------------+
# |polarity|count(polarity)|
# +--------+---------------+
# |       4|            180|
# |       2|            113|
# |       0|            205|
# +--------+---------------+
# ```
# **0.47**
#
# **0.45**

# %%
final_df = final.select('id','polarity').toPandas()
final_df.to_csv('submission.csv', header=True, index=False)

# %%
final_df
# Out:
#         id  polarity
# 0        3         4
# 1        4         4
# 2        5         4
# 3        6         0
# 4        7         4
# ..     ...       ...
# 493  14072         2
# 494  14073         0
# 495  14074         4
# 496  14075         0
# 497  14076         0
#
# [498 rows x 2 columns]

# %% [markdown]
# ### Accuracy

# %%
test_data = spark.read.csv('/content/drive/MyDrive/TÀI LIỆU HỌC TẬP ĐẠI HỌC 2019-2023/NĂM 3 2021-2022/HỌC KỲ 2 2021 - 2022/DS200.M21 - PHÂN TÍCH DỮ LIỆU LỚN/THỰC HÀNH/LAB/Lab SparkML - 28 04 2022/Slide 10 - PySpark dataset/testdata.manual.2009.06.14.csv', header=False, schema=schemaTrain).select('id', 'polarity')
# test_data.show()
# test_data.count()

# %%
final_test = final.select('id','polarity')
# final_test.show()
# final_test.count()

# %%
y_true = test_data.select('polarity').toPandas()
# y_true

# %%
y_pred = final_test.select('polarity').toPandas()
# y_pred

# %%
import sklearn
acc = sklearn.metrics.accuracy_score(y_true, y_pred)
print(f'Accuracy: {acc*100:.5f}%')
# Out:
# Accuracy: 69.07631%

# %% [markdown]
# ```
# Accuracy: 69.07631%
# ```

# %% [markdown]
# **Best Accuracy**
# ```python
# 0.6907630522088354
# ```
